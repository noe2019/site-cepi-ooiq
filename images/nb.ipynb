# %%
import os
from PIL import Image

for file in os.listdir():
    if file.endswith(".jpg"):
        img = Image.open(file)
        new_name = file.replace(".jpg", ".webp")
        img.save(new_name, "WEBP", quality=80)

# %%
# !pip install pillow

from PIL import Image

img = Image.open("favicon.png")

# Redimensionner en 256x256 (taille idéale favicon moderne)
img = img.resize((256, 256))

# Sauvegarder en .ico
img.save("favicon.ico", format="ICO")
# Out:
# Requirement already satisfied: pillow in c:\users\noefo\appdata\local\programs\python\python311\lib\site-packages (10.4.0)
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: C:\Users\noefo\AppData\Local\Programs\Python\Python311\python.exe -m pip install --upgrade pip

# %%
#!pip install opencv-python
#import cv2
import numpy as np
from potrace import Bitmap

# Convertir en noir/blanc
img = cv2.imread("logo.png", 0)
_, img_bin = cv2.threshold(img, 127, 255, cv2.THRESH_BINARY)

# Vectoriser avec potrace
bmp = Bitmap(img_bin)
path = bmp.trace()

with open("logo.svg", "w") as f:
    f.write(path.to_svg())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 7
#       3 import numpy as np
#       4 #from potrace import Bitmap
#       5
#       6 # Convertir en noir/blanc
# ----> 7 img = cv2.imread("logo.png", 0)
#       8 _, img_bin = cv2.threshold(img, 127, 255, cv2.THRESH_BINARY)
#      10 # Vectoriser avec potrace
#
# NameError: name 'cv2' is not defined
